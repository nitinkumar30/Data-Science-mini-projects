# %%
# import required libraries
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# data from ohio state, leading causes of death in the state from year 2012
# Cause of death
cause = 'Chronic Disease', 'Unintetional Injuries', 'Alzheimers', 'Infuenza and Pneumonia', 'Sepsis','Others'

# percentile
percentile = [62, 5, 4, 2, 1 , 26]

# %%
# set the pie chart plot properties
# set figure size
plt.figure(figsize=(10,10))

# explode the largest pie in the datase
explode = (0.05,0,0,0,0,0)

# set pie chart properties
plt.pie(percentile, labels=cause, explode=explode, autopct='%1.1f%%', startangle=70)

# set axis equal to the draw pie as circle
plt.axis('equal')

# set title of the pie chart
plt.title('Ohio state 2012 - Leading death cause')

# show the plot (pie chart)
plt.show()
